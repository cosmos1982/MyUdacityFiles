# %% [markdown]
# ## 探索电影数据集
#
# 在这个项目中，你将尝试使用所学的知识，使用 `NumPy`、`Pandas`、`matplotlib`、`seaborn` 库中的函数，来对电影数据集进行探索。
#
# 下载数据集：
# [TMDb电影数据](https://s3.cn-north-1.amazonaws.com.cn/static-documents/nd101/explore+dataset/tmdb-movies.csv)

# %% [markdown]
# 数据集各列名称的含义：
# <table>
# <thead><tr><th>列名称</th><th>id</th><th>imdb_id</th><th>popularity</th><th>budget</th><th>revenue</th><th>original_title</th><th>cast</th><th>homepage</th><th>director</th><th>tagline</th><th>keywords</th><th>overview</th><th>runtime</th><th>genres</th><th>production_companies</th><th>release_date</th><th>vote_count</th><th>vote_average</th><th>release_year</th><th>budget_adj</th><th>revenue_adj</th></tr></thead><tbody>
#  <tr><td>含义</td><td>编号</td><td>IMDB 编号</td><td>知名度</td><td>预算</td><td>票房</td><td>名称</td><td>主演</td><td>网站</td><td>导演</td><td>宣传词</td><td>关键词</td><td>简介</td><td>时常</td><td>类别</td><td>发行公司</td><td>发行日期</td><td>投票总数</td><td>投票均值</td><td>发行年份</td><td>预算（调整后）</td><td>票房（调整后）</td></tr>
# </tbody></table>

# %% [markdown]
# **请注意，你需要提交该报告导出的 `.html`、`.ipynb` 以及 `.py` 文件。**

# %% [markdown]
# ---
#
# ---
#
# ## 第一节 数据的导入与处理
#
# 在这一部分，你需要编写代码，使用 Pandas 读取数据，并进行预处理。

# %% [markdown]
# **任务1.1：** 导入库以及数据
#
# 1. 载入需要的库 `NumPy`、`Pandas`、`matplotlib`、`seaborn`。
# 2. 利用 `Pandas` 库，读取 `tmdb-movies.csv` 中的数据，保存为 `movie_data`。
#
# 提示：记得使用 notebook 中的魔法指令 `%matplotlib inline`，否则会导致你接下来无法打印出图像。

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

movie_data = pd.read_csv('./Data/tmdb-movies.csv', parse_dates=['release_date']);

# %% [markdown]
# ---
#
# **任务1.2: ** 了解数据
#
# 你会接触到各种各样的数据表，因此在读取之后，我们有必要通过一些简单的方法，来了解我们数据表是什么样子的。
#
# 1. 获取数据表的行列，并打印。
# 2. 使用 `.head()`、`.tail()`、`.sample()` 方法，观察、了解数据表的情况。
# 3. 使用 `.dtypes` 属性，来查看各列数据的数据类型。
# 4. 使用 `isnull()` 配合 `.any()` 等方法，来查看各列是否存在空值。
# 5. 使用 `.describe()` 方法，看看数据表中数值型的数据是怎么分布的。

# %%
print(movie_data.shape)
movie_data.head()

#查看各列数据的数据类型
for col_name in movie_data.columns:
    print("Data type for Column '{}' is {}".format(col_name, movie_data[col_name].dtypes)) 

print()
#查看各列是否存在空值
for col_name in movie_data.columns:
    if movie_data[col_name].isnull().any():
       print("Column '{}' has Nans.".format(col_name))

print()
#查看数据如何分布
movie_data.describe()
# Out:
# (10866, 21)
# Data type for Column 'id' is int64
# Data type for Column 'imdb_id' is object
# Data type for Column 'popularity' is float64
# Data type for Column 'budget' is int64
# Data type for Column 'revenue' is int64
# Data type for Column 'original_title' is object
# Data type for Column 'cast' is object
# Data type for Column 'homepage' is object
# Data type for Column 'director' is object
# Data type for Column 'tagline' is object
# Data type for Column 'keywords' is object
# Data type for Column 'overview' is object
# Data type for Column 'runtime' is int64
# Data type for Column 'genres' is object
# Data type for Column 'production_companies' is object
# Data type for Column 'release_date' is datetime64[ns]
# Data type for Column 'vote_count' is int64
# Data type for Column 'vote_average' is float64
# Data type for Column 'release_year' is int64
# Data type for Column 'budget_adj' is float64
# Data type for Column 'revenue_adj' is float64
#
# Column 'imdb_id' has Nans.
# Column 'cast' has Nans.
# Column 'homepage' has Nans.
# Column 'director' has Nans.
# Column 'tagline' has Nans.
# Column 'keywords' has Nans.
# Column 'overview' has Nans.
# Column 'genres' has Nans.
# Column 'production_companies' has Nans.
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# std      575.619058      0.935142     12.812941  3.430616e+07  1.446325e+08
# min       10.000000      1.500000   1960.000000  0.000000e+00  0.000000e+00
# 25%       17.000000      5.400000   1995.000000  0.000000e+00  0.000000e+00
# 50%       38.000000      6.000000   2006.000000  0.000000e+00  0.000000e+00
# 75%      145.750000      6.600000   2011.000000  2.085325e+07  3.369710e+07
# max     9767.000000      9.200000   2015.000000  4.250000e+08  2.827124e+09

# %% [markdown]
# ---
#
# **任务1.3: ** 清理数据
#
# 在真实的工作场景中，数据处理往往是最为费时费力的环节。但是幸运的是，我们提供给大家的 tmdb 数据集非常的「干净」，不需要大家做特别多的数据清洗以及处理工作。在这一步中，你的核心的工作主要是对数据表中的空值进行处理。你可以使用 `.fillna()` 来填补空值，当然也可以使用 `.dropna()` 来丢弃数据表中包含空值的某些行或者列。
#
# 任务：使用适当的方法来清理空值，并将得到的数据保存。

# %%
#丢弃有nan的行数据
movie_data = movie_data.dropna()

# %% [markdown]
# ---
#
# ---
#
# ## 第二节 根据指定要求读取数据
#
#
# 相比 Excel 等数据分析软件，Pandas 的一大特长在于，能够轻松地基于复杂的逻辑选择合适的数据。因此，如何根据指定的要求，从数据表当获取适当的数据，是使用 Pandas 中非常重要的技能，也是本节重点考察大家的内容。

# %% [markdown]
# ---
#
# **任务2.1: ** 简单读取
#
# 1. 读取数据表中名为 `id`、`popularity`、`budget`、`runtime`、`vote_average` 列的数据。
# 2. 读取数据表中前1～20行以及48、49行的数据。
# 3. 读取数据表中第50～60行的 `popularity` 那一列的数据。
#
# 要求：每一个语句只能用一行代码实现。

# %%
data1 = movie_data[['id', 'popularity', 'budget', 'runtime', 'vote_average']];
data2 = movie_data.iloc[list(range(0,20)) + [47, 48]];
data3 = movie_data.iloc[list(range(49,60))]['popularity'];

# %% [markdown]
# ---
#
# **任务2.2: **逻辑读取（Logical Indexing）
#
# 1. 读取数据表中 **`popularity` 大于5** 的所有数据。
# 2. 读取数据表中 **`popularity` 大于5** 的所有数据且**发行年份在1996年之后**的所有数据。
#
# 提示：Pandas 中的逻辑运算符如 `&`、`|`，分别代表`且`以及`或`。
#
# 要求：请使用 Logical Indexing实现。

# %%
data1 = movie_data[movie_data['popularity'] > 5];
data2 = movie_data[(movie_data['popularity'] > 5) & (movie_data['release_year'] > 1996)]

# %% [markdown]
# ---
#
# **任务2.3: **分组读取
#
# 1. 对 `release_year` 进行分组，使用 [`.agg`](http://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.core.groupby.DataFrameGroupBy.agg.html) 获得 `revenue` 的均值。
# 2. 对 `director` 进行分组，使用 [`.agg`](http://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.core.groupby.DataFrameGroupBy.agg.html) 获得 `popularity` 的均值，从高到低排列。
#
# 要求：使用 `Groupby` 命令实现。

# %%
revenue_mean = movie_data.groupby(['release_year']).agg({'revenue': 'mean'})
popularity_mean = movie_data.groupby(['director']).agg({'popularity': 'mean'})
popularity_mean.sort_values('popularity', ascending=False, inplace=True)
#popularity_mean.head()

# %% [markdown]
# ---
#
# ---
#
# ## 第三节 绘图与可视化
#
# 接着你要尝试对你的数据进行图像的绘制以及可视化。这一节最重要的是，你能够选择合适的图像，对特定的可视化目标进行可视化。所谓可视化的目标，是你希望从可视化的过程中，观察到怎样的信息以及变化。例如，观察票房随着时间的变化、哪个导演最受欢迎等。
#
# <table>
# <thead><tr><th>可视化的目标</th><th>可以使用的图像</th></tr></thead><tbody>
#  <tr><td>表示某一属性数据的分布</td><td>饼图、直方图、散点图</td></tr>
#  <tr><td>表示某一属性数据随着某一个变量变化</td><td>条形图、折线图、热力图</td></tr>
#  <tr><td>比较多个属性的数据之间的关系</td><td>散点图、小提琴图、堆积条形图、堆积折线图</td></tr>
# </tbody></table>
#
# 在这个部分，你需要根据题目中问题，选择适当的可视化图像进行绘制，并进行相应的分析。对于选做题，他们具有一定的难度，你可以尝试挑战一下～

# %% [markdown]
# **任务3.1：**对 `popularity` 最高的20名电影绘制其 `popularity` 值。

# %%
top_movies = movie_data.sort_values('popularity', ascending=False)[0:20];
#top_movies[['popularity']].plot(kind='bar')
#plt.show()
plt.figure(figsize = [5, 10]);
plt.subplot(2, 1, 1);
bin_edges = np.arange(top_movies['popularity'].min(), top_movies['popularity'].max()+0.5, 0.5);
plt.hist(data = top_movies, x = 'popularity', bins = bin_edges);


plt.subplot(2, 1, 2);
plt.pie(top_movies['popularity'], labels = top_movies.original_title, startangle = 90,
        counterclock = False);
plt.axis('square');

# %% [markdown]
# ---
# **任务3.2：**分析电影净利润（票房-成本）随着年份变化的情况，并简单进行分析。

# %%
profit_adj = movie_data['revenue_adj'] - movie_data['budget_adj'];

#改变profit_adj的单位
movie_data['profit_adj'] = profit_adj/(np.e**14);
movie_profit_mean = movie_data.groupby('release_year').agg({'profit_adj': 'mean'})
year_counts = movie_data.groupby('release_year').size()
year_counts.reset_index(name = 'count')
cdata = pd.concat([movie_profit_mean, year_counts], axis=1);

#为了验证画图的正确性，使用了柱状图和折线图两种分别进行可视化
#第一张图：绘制条形图，展示利润均值和电影数量
fig = plt.figure(figsize = [18, 10])
ax = fig.add_subplot(2, 1, 1)
cdata.plot.bar(ax = ax)

#第二张图，折线图
fig.add_subplot(2, 1, 2)
xbin_edges = np.arange( movie_data['release_year'].min(), movie_data['release_year'].max()+1, 1)
xbin_centers = (xbin_edges + 1)[:-1]

# compute statistics in each bin
data_xbins = pd.cut(movie_data['release_year'], xbin_edges, right = False, include_lowest = True)
y_means = movie_data['profit_adj'].groupby(data_xbins).mean()
y_sems = movie_data['profit_adj'].groupby(data_xbins).sem()

# plot the summarized data
plt.errorbar(x = xbin_centers, y = y_means, yerr = y_sems)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# <h3>分析结论：</h3>
# 随着年代的增加，电影的数据越来越多，但电影的利润反而越来越低。

# %% [markdown]
# ---
#
# **[选做]任务3.3：**选择最多产的10位导演（电影数量最多的），绘制他们排行前3的三部电影的票房情况，并简要进行分析。

# %%
#此处排行前3没有说明是什么排行前3，因此取popularity的前三。
movie_counts = movie_data.groupby('director').size()
top_directors = movie_counts.sort_values(ascending=False)[0:10];
top1_data = []
top2_data = []
top3_data = []
#print(type(top_directors))
for director in top_directors.index:
    movies_of_director = movie_data[movie_data['director'] == director].sort_values('popularity', ascending=False)[0:3]
    top1_data.append(movies_of_director['revenue'].values[0])
    top2_data.append(movies_of_director['revenue'].values[1])
    top3_data.append(movies_of_director['revenue'].values[2])

revenue_data = pd.DataFrame(data = {'top1': top1_data, 'top2': top2_data, 'top3': top3_data}, index=top_directors.index.values)
print(revenue_data)

fig = plt.figure(figsize = [15, 5])
ax = fig.add_subplot(1, 1, 1)
revenue_data.plot.bar(ax = ax)
# Out:
#                          top1       top2       top3
# John Carpenter       13782838   70000000   50000000
# Steven Soderbergh   450717150  362744280  167221571
# Steven Spielberg    389925971  474171806  786636033
# Robert Zemeckis     381109762  332000000  244527583
# Ridley Scott        595380321  104931801   32768670
# Peter Jackson       955119788  871368364  926287400
# Clint Eastwood      542307423  269958228  216763646
# Ron Howard          758239851  345141403  356613439
# Paul W.S. Anderson  102441078   73762516  132274484
# Martin Scorsese     392000694  294804195  289847354

# %% [markdown]
# <h3>分析结论：</h3>
# 1.最卖座的导演是Peter Jackson, 票房分布平均且是所有电影票房中最高的，远超其它导演。<br>
# 2.导演Ridley Scott的最受欢迎电影中，票房的差异巨大，说明这位导演赚钱能力不稳定。<br>
# 3.导演John Carpenter虽然多产，但票房都很惨淡。<br>

# %% [markdown]
# ---
#
# **[选做]任务3.4：**分析1968年~2015年六月电影的数量的变化。

# %%
movie_data['release_year_month'] = movie_data['release_date'].map(lambda x:100*x.year + x.month)
selected_movie = movie_data[(movie_data['release_year_month'] >= 196801) & (movie_data['release_year_month'] <= 201506)]
selected_movie.head()
# Out:
#        id    imdb_id  popularity     budget     revenue      original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810      Jurassic World
# 1   76341  tt1392190   28.419936  150000000   378436354  Mad Max: Fury Road
# 2  262500  tt2908446   13.112507  110000000   295238201           Insurgent
# 4  168259  tt2820852    9.335014  190000000  1506249360           Furious 7
# 6   87101  tt1340138    8.654359  155000000   440603537  Terminator Genisys
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
# 6  Arnold Schwarzenegger|Jason Clarke|Emilia Clar...
#
#                                          homepage          director  \
# 0                   http://www.jurassicworld.com/   Colin Trevorrow
# 1                     http://www.madmaxmovie.com/     George Miller
# 2  http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
# 4                        http://www.furious7.com/         James Wan
# 6                 http://www.terminatormovie.com/       Alan Taylor
#
#                       tagline         ...          \
# 0           The park is open.         ...
# 1          What a Lovely Day.         ...
# 2  One Choice Can Destroy You         ...
# 4         Vengeance Hits Home         ...
# 6            Reset the future         ...
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 4                      Action|Crime|Thriller
# 6  Science Fiction|Action|Thriller|Adventure
#
#                                 production_companies  release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...    2015-06-09       5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...    2015-05-13       6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...    2015-03-18       2480
# 4  Universal Pictures|Original Film|Media Rights ...    2015-04-01       2947
# 6            Paramount Pictures|Skydance Productions    2015-06-23       2598
#
#   vote_average release_year    budget_adj   revenue_adj   profit_adj  \
# 0          6.5         2015  1.379999e+08  1.392446e+09  1043.107837
# 1          7.1         2015  1.379999e+08  3.481613e+08   174.755201
# 2          6.3         2015  1.012000e+08  2.716190e+08   141.708351
# 4          7.3         2015  1.747999e+08  1.385749e+09  1006.938770
# 6          5.8         2015  1.425999e+08  4.053551e+08   218.488444
#
#    release_year_month
# 0              201506
# 1              201505
# 2              201503
# 4              201504
# 6              201506
#
# [5 rows x 23 columns]

# %%
# 绘制散点图
selected_movies_counts = selected_movie.groupby('release_year_month').size().reset_index(name='count')

selected_movies_counts.head()
fig = plt.figure(figsize = [15, 5]);
ax = fig.add_subplot(1, 1, 1);
sb.regplot('release_year_month', 'count', data = selected_movies_counts)

# %%
#任意绘制年度数据，观察一年内每个月份的数据变化
def show_figure(year, ax):
    sb.regplot('release_year_month', 'count', data = selected_movies_counts)
    ax.set_xlim([year*100+1, year*100+12])
    ax.set_xticks(list(range(year*100+1, year*100+13, 1)))
    xtick_label = ["{}-{:0>2d}".format(x//100, x%100) for x in ax.get_xticks()]
    ax.set_xticklabels(xtick_label)
    for tick in ax.xaxis.get_major_ticks():
        #tick.label.set_fontsize(10)
        tick.label.set_rotation(30)
    ax.set_title('Monthly movie count statics in ' + str(year))
    plt.xlabel('')
    plt.ylabel('Movie count')

fig = plt.figure(figsize = [16, 10]);
ax = fig.add_subplot(2, 2, 1);
show_figure(2009, ax)

ax = fig.add_subplot(2, 2, 2);
show_figure(2011, ax)

ax = fig.add_subplot(2, 2, 3);
show_figure(2012, ax)

ax = fig.add_subplot(2, 2, 4);
show_figure(2014, ax)

plt.subplots_adjust(hspace=0.3, wspace=0.2)

# %% [markdown]
# <h3>任务3.4结论</h3><br>
# 1.整体上来看，从1968年到2015年，电影的数量是逐渐上升的；<br>
# 2.单独分析2009, 2011, 2012, 2014年的数据,可以看出电影数量在暑期档最多。

# %% [markdown]
# ---
#
# **[选做]任务3.5：**分析1968年~2015年六月电影 `Comedy` 和 `Drama` 两类电影的数量的变化。

# %%
selected_comedy_movies = movie_data[(movie_data['release_year_month'] >= 196801) & (movie_data['release_year_month'] <= 201506) & (movie_data['genres']=='Comedy')]
selected_comedy_movies_count = selected_comedy_movies.groupby('release_year_month').size().reset_index(name = 'comedy_count')
#selected_comedy_movies_count = selected_comedy_movies_count.set_index('release_year_month')

selected_drama_movies = movie_data[(movie_data['release_year_month'] >= 196801) & (movie_data['release_year_month'] <= 201506) & (movie_data['genres']=='Drama')]
selected_drama_movies_count = selected_drama_movies.groupby('release_year_month').size().reset_index(name = 'drama_count')
selected_drama_movies_count1 = selected_drama_movies_count.set_index('release_year_month')

print(selected_drama_movies_count.head())

#绘制comedy数量图
fig = plt.figure(figsize = [16, 15]);
ax = fig.add_subplot(3, 1, 1);
selected_drama_movies_count1.plot(ax = ax, linestyle='dashed')
#sb.regplot('release_year_month', 'comedy_count', data = selected_comedy_movies_count)
#ax.set_xlim([selected_drama_movies_count['release_year_month'].min(), selected_drama_movies_count['release_year_month'].max()+1])
#ax.set_xticks([selected_drama_movies_count['release_year_month']])
#print(ax.get_xticks())
#xtick_label = ["{}-{:0>2d}".format(x//100, x%100) for x in ax.get_xticks()]
#ax.set_xticklabels(xtick_label)
ax.set_title('Movies count of Comedy During 1968 - 2015-06')
plt.xlabel('')

#绘制drama数量图
ax = fig.add_subplot(3, 1, 2);
#xtick_label = ["{}-{:0>2d}".format(x//100, x%100) for x in ax.get_xticks()]
#ax.set_xticklabels(xtick_label)
ax.set_title('Movies count of Drama During 1968 - 2015-06')
plt.xlabel('')

#绘制comedy和drama一起的条形图
result = pd.merge(selected_comedy_movies_count,selected_drama_movies_count, on='release_year_month', how = 'outer')
result = result.fillna(0).set_index('release_year_month')
result.sort_index(inplace = True)

ax = fig.add_subplot(3, 1, 3);
result.plot.bar(ax=ax);
ax.set_xticks(ax.get_xticks()[::6]);
ax.set_xticklabels(["{}-{:0>2d}".format(x//100, x%100) for x in result.index[::6]]);

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_rotation(30)
ax.set_title('Movies count of Comedy and Drama During 1968 - 2015-06')
plt.xlabel('')
# Out:
#    release_year_month  drama_count
# 0              197110            1
# 1              199712            1
# 2              199810            1
# 3              199907            1
# 4              199909            1
# Text(0.5,0,'')

# %% [markdown]
# <h3>选作任务3.5结论</h3><br>

# %% [markdown]
# > 注意: 当你写完了所有的代码，并且回答了所有的问题。你就可以把你的 iPython Notebook 导出成 HTML 文件。你可以在菜单栏，这样导出**File -> Download as -> HTML (.html)、Python (.py)** 把导出的 HTML、python文件 和这个 iPython notebook 一起提交给审阅者。
